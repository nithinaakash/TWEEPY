# %%
import twitter_credential as tc
import tweepy
from tweepy import API 
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import time
from time import sleep

import csv

import numpy as np
import pandas as pd
auth =OAuthHandler(tc.consumer_token, tc.consumer_sec)
auth.set_access_token(tc.access_token, tc.access_sec)
api = API(auth,wait_on_rate_limit=True)
with open('student.csv', mode='w') as student_file:
        student_writer = csv.writer(student_file)
        for f in tweepy.Cursor(api.followers, screen_name="bijanm").items():
            student_writer.writerow([f.name,f.id ,f.created_at,f.description])
            print (f.id , f.name,f.created_at,f.description)
with open('new.csv', mode='w') as new_file:
        new_writer = csv.writer(new_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL) 
        for f in tweepy.Cursor(api.friends, screen_name="bijanm").items():
            new_writer.writerow( [f.name,f.id ,f.created_at,f.description])
            print (f.id , f.name,f.created_at,f.description)
# Out:
# 1119329116908654592 Selma Moseler 2019-04-19 19:57:12
# 720863 Tom Lee 2007-01-28 18:49:19 Policy @ Mapbox. Before: CTO @ Sunlight Foundation. Other than that my Github's mostly firmware for Halloween costumes.
# 24540682 Carl Gottlieb 2009-03-15 15:54:18 Data Protection Officer: @duolingo @hudl Owner: https://t.co/dOknv5dAmc, https://t.co/GDW4mJX7sR, https://t.co/dzKQ3S4ivb, Podcaster: https://t.co/uuwT2jc9bG @c2_fm Views my own
# 900809394 Brendan Kittredge 2012-10-23 23:51:54 Co-Founder @secretnodes
# 179062729 Andi Arias 2010-08-16 12:06:09 Privacy & data security attorney @FTC. Geek. Gamer. Sci-fi afficionado. Fútbol and bball diehard. But most important: Mom. Views = own.
# 1462508754 Lincoln Network 🚀🤖🇺🇸 2013-05-27 16:10:30 Join us to help bridge the gap between Silicon Valley and DC, and make a more perfect union between policy and innovation.
# ...
